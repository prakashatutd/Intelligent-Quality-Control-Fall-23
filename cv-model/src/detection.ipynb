# %%
from ultralytics import YOLO
from PIL import Image

# %%
trained_model = YOLO("best.pt")

# %%
results = trained_model("../images/dented-can.jpeg", conf=0.4)
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    display(im)
# Out:
# image 1/1 /Users/shreyakuntumalla/Desktop/UTD21-25/semesters/Fall23/Intelligent-Quality-Detection-System/cv-model/src/../images/dented-can.jpeg: 544x800 1 Dent_Can, 460.1ms
# Speed: 2.8ms preprocess, 460.1ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 800)
# <PIL.Image.Image image mode=RGB size=450x300>

# %%
results = trained_model("../images/lid-open.jpeg", conf=0.25)
for r in results:
    im_array = r[1].plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    display(im)
# Out:
# image 1/1 /Users/shreyakuntumalla/Desktop/UTD21-25/semesters/Fall23/Intelligent-Quality-Detection-System/cv-model/src/../images/lid-open.jpeg: 800x544 1 Lid_Open, 1 Tin_Can, 417.6ms
# Speed: 3.3ms preprocess, 417.6ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 544)
# <PIL.Image.Image image mode=RGB size=408x612>
